# %% [markdown]
# # ***Content-Based Recommender***

# %% [markdown]
# # ***Pyspark***

# %%
pip install pyspark
# Out:
# Collecting pyspark
#   Downloading https://files.pythonhosted.org/packages/45/b0/9d6860891ab14a39d4bddf80ba26ce51c2f9dc4805e5c6978ac0472c120a/pyspark-3.1.1.tar.gz (212.3MB)
#      |████████████████████████████████| 212.3MB 67kB/s
# Collecting py4j==0.10.9
#   Downloading https://files.pythonhosted.org/packages/9e/b6/6a4fb90cd235dc8e265a6a2067f2a2c99f0d91787f06aca4bcf7c23f3f80/py4j-0.10.9-py2.py3-none-any.whl (198kB)
#      |████████████████████████████████| 204kB 34.7MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.1.1-py2.py3-none-any.whl size=212767604 sha256=4a3e2658254478b0dd9fa6d62336f9d33ae23c17bfcef66d6a76b6185b798fad
#   Stored in directory: /root/.cache/pip/wheels/0b/90/c0/01de724414ef122bd05f056541fb6a0ecf47c7ca655f8b3c0f
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9 pyspark-3.1.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Movies Recommendation").config("spark.driver.memory","15g").config("spark.executor.memory", "15g").getOrCreate()

# %%
credits = spark.read.csv('/content/drive/MyDrive/Colab Notebooks/credits.csv',header=True, inferSchema=True)
keywords =spark.read.csv('/content/drive/MyDrive/Colab Notebooks/keywords.csv',header=True,inferSchema=True,escape='\"')
metadata = spark.read.csv('/content/drive/MyDrive/Colab Notebooks/movies_metadata.csv',header=True,inferSchema=True).limit(30000)

# %%
df = metadata.join(keywords,on=['id'])
df = df.join(credits,on=['id'])

# %%
print(metadata.count())
print(keywords.count())
print(credits.count())
# Out:
# 30000
# 46419
# 45476

# %%
df.count()
# Out:
# 18704

# %%
# df.toPandas()

# %%
from pyspark.sql.types import StringType,ArrayType
from pyspark.sql.functions import col, udf

# %%
# keywords.where(col("id")=="4975").collect()[0]["keywords"]

# %%
# df.where(col("id")=="1265").collect()[0]["keywords"]

# %%
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        #Check if director exists. If not, return empty string
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
import numpy as np
def get_director(x):
    for i in eval(x):
        if i['job'] == 'Director':
            return clean_data(i['name'])
    return clean_data(np.nan)

# %%
def get_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        #Check if more than 3 elements exist. If yes, return only first three. If no, return entire list.
        if len(names) > 3:
            names = names[:3]
        return clean_data(names)

    #Return empty list in case of missing/malformed data
    return clean_data([])

# %%
from ast import literal_eval
def literal_eval_convert(x):
    return get_list(eval(x))

# %%
convert_UDF = udf(lambda x: literal_eval_convert(x) if x is not None else None)
get_director_UDF = udf(lambda x: get_director(x) if x is not None else None)

# %%
from pyspark.sql.functions import col, udf
features = ['cast', 'crew', 'keywords', 'genres']
df_1=df.withColumn("cast",convert_UDF("cast"))

# %%
# df_1.collect()

# %%
df_2=df_1.withColumn("keywords",convert_UDF("keywords"))

# %%
# df_2.toPandas()

# %%
df_3=df_2.withColumn("genres",convert_UDF("genres"))

# %%
# df_3.collect()

# %%
df_4=df_3.withColumn("director",get_director_UDF("crew"))

# %%
# df_4.collect()

# %%
df_5 = df_4.select('cast', 'director', 'keywords', 'genres','title','id')

# %%
# df_5.collect()

# %%
def create_soup( cast,director,keywords,genres):
    # print(type( x['keywords']))
    return ' '.join(keywords.strip('][').split(', ')) + ' ' + ' '.join(cast.strip('][').split(', ')) + ' ' + director + ' ' + ' '.join(genres.strip('][').split(', '))

# %%
#  a=df_5.collect()[0]

# %%
# create_soup({"cast":a["cast"],"director":a["director"],"keywords":a["keywords"],"genres":a["genres"]})

# %%
create_soup_UDF = udf(lambda cast,director,keywords,genres: create_soup(cast,director,keywords,genres))

# %%
df_6 = df_5.withColumn("features",create_soup_UDF(col("cast"),col("director"),col("keywords"),col("genres")))

# %%
# df_6.collect()

# %%
from pyspark.sql.functions import monotonically_increasing_id,row_number
from pyspark.sql import Window
# This will return a new DF with all the columns + id
# df_7 = df_6.withColumn("id", monotonically_increasing_id())
window = Window.orderBy(col('id'))
df_7 = df_6.withColumn('index', row_number().over(window))

# %%
data = df_7.select("features").orderBy("index").rdd.flatMap(lambda x: x).collect()

# %%
# df_7.orderBy("index").show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+------+--------------------+-----+
# |                cast|            director|            keywords|              genres|               title|    id|            features|index|
# +--------------------+--------------------+--------------------+--------------------+--------------------+------+--------------------+-----+
# |                  []|       sergiocabrera|[roommate, pastor...|     [comedy, drama]|La estrategia del...| 10000|roommate pastor s...|    1|
# |[kaorufutaba, mic...|      hiroshishimizu|       [countryside]|             [drama]|       Mr. Thank You|100033|countryside kaoru...|    2|
# |[jamesmitchum, ro...|         eddymatalon|[terror, blackout...|  [action, thriller]|            Blackout|100063|terror blackout c...|    3|
# |[michaelj.pagan, ...|         gregorydark|[hotel, eyeball, ...|  [horror, thriller]|         See No Evil| 10007|hotel eyeball mur...|    4|
# |[josefinacembrero...|        martaarribas|     [womandirector]|                  []|El tren de la mem...|100085|womandirector jos...|    5|
# |[jimbrown, martin...|roberthartford-davis|    [blaxploitation]|[action, thriller...|          Black Gunn|100088|blaxploitation ji...|    6|
# |[dominiqueswain, ...|      josephj.lawson|[femalenudity, cy...|[adventure, horro...|Nazis at the Cent...|100089|femalenudity cybo...|    7|
# |[joaquinphoenix, ...|         aaronblaise|[brotherbrotherre...|[adventure, anima...|        Brother Bear| 10009|brotherbrotherrel...|    8|
# |[mattmccoy, haley...|        ryanschifrin|[femalenudity, ca...|  [horror, thriller]|          Abominable| 10011|femalenudity cave...|    9|
# |[felemartínez, ma...|álvarofernándezar...|                  []|[horror, thriller...|    The Art of Dying|100122| felemartínez mar...|   10|
# |[robertenglund, m...|         jacksholder|[gay, dancing, fire]|            [horror]|A Nightmare on El...| 10014|gay dancing fire ...|   11|
# |[jamesrusso, timr...|     buddygiovinazzo|[stripclub, drug,...|             [drama]|         No Way Home|100167|stripclub drug ex...|   12|
# |[jürgenvogel, chr...|      wolfgangbecker|[berlin, newlove,...|[romance, drama, ...| Life Is All You Get| 10018|berlin newlove st...|   13|
# |[catherinesteadma...|         stevebarker|[bunker, nazis, e...|    [action, horror]|  Outpost: Black Sun|100183|bunker nazis east...|   14|
terwaldtjr. comedy', 'rebel showdown landmine theresarandle markdacascos jefffahey henrycrum action adventure thriller', 'ransom pressconference ship sandrabullock reginaking enriquemurciano johnpasquin action comedy', 'womandirector  sophiefiennes foreign', 'forest self-inflictedinjury psychopath ericcolvin nadjabrand abbeystirling adammason horror thriller', ' r.kelly catwilson rolandoboyce r.kelly ', 'japanesenewwave hashizookawa satomioka rentarômikuni nagisaōshima drama history war', 'lighthouse lighthousekeeper michaelredgrave barbaramullen jamesmason royboulting drama fantasy war', 'bestfriend gretagerwig joelkinnaman billpullman darylwein comedy', 'womandirector  adilavy documentary romance', 'doublelife parentchildrelationship brothersisterrelationship alexapenavega darylsabara antoniobanderas robertrodriguez action comedy family', ' chadwickboseman torykittles billyzane mischawebley action', 'newyork womanbetweentwomen hoodlum franksilvera jamiesmith irenekane stanleykubrick crime drama thriller', 'terror plant flowerpot  jiřítrnka animation drama', ' juha-pekkamikkola tonyhalme teromolin action horror sciencefiction', 'prison usapresident earthquake kurtrussell stacykeach stevebuscemi johncarpenter action adventure sciencefiction', 'exoticisland baseballbat vacation michellerodriguez tarynmanning ericlively ...

# %%
# df_6.toPandas()

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(data)

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim = cosine_similarity(count_matrix,count_matrix)

# %%
# print(cosine_sim.shape)

# %%
# ('dict', list, 'series', 'split', 'records', 'index')

# %%
# dict_data= df.select('id','title').toPandas().set_index('title').T.to_dict("list")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   """Entry point for launching an IPython kernel.

# %%
# df_final.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+------+--------------------+-----+
# |                cast|            director|            keywords|              genres|               title|    id|            features|index|
# +--------------------+--------------------+--------------------+--------------------+--------------------+------+--------------------+-----+
# |                  []|       sergiocabrera|[roommate, pastor...|     [comedy, drama]|La estrategia del...| 10000|roommate pastor s...|    1|
# |[kaorufutaba, mic...|      hiroshishimizu|       [countryside]|             [drama]|       Mr. Thank You|100033|countryside kaoru...|    2|
# |[jamesmitchum, ro...|         eddymatalon|[terror, blackout...|  [action, thriller]|            Blackout|100063|terror blackout c...|    3|
# |[michaelj.pagan, ...|         gregorydark|[hotel, eyeball, ...|  [horror, thriller]|         See No Evil| 10007|hotel eyeball mur...|    4|
# |[josefinacembrero...|        martaarribas|     [womandirector]|                  []|El tren de la mem...|100085|womandirector jos...|    5|
# |[jimbrown, martin...|roberthartford-davis|    [blaxploitation]|[action, thriller...|          Black Gunn|100088|blaxploitation ji...|    6|
# |[dominiqueswain, ...|      josephj.lawson|[femalenudity, cy...|[adventure, horro...|Nazis at the Cent...|100089|femalenudity cybo...|    7|
# |[joaquinphoenix, ...|         aaronblaise|[brotherbrotherre...|[adventure, anima...|        Brother Bear| 10009|brotherbrotherrel...|    8|
# |[mattmccoy, haley...|        ryanschifrin|[femalenudity, ca...|  [horror, thriller]|          Abominable| 10011|femalenudity cave...|    9|
# |[felemartínez, ma...|álvarofernándezar...|                  []|[horror, thriller...|    The Art of Dying|100122| felemartínez mar...|   10|
# |[robertenglund, m...|         jacksholder|[gay, dancing, fire]|            [horror]|A Nightmare on El...| 10014|gay dancing fire ...|   11|
# |[jamesrusso, timr...|     buddygiovinazzo|[stripclub, drug,...|             [drama]|         No Way Home|100167|stripclub drug ex...|   12|
# |[jürgenvogel, chr...|      wolfgangbecker|[berlin, newlove,...|[romance, drama, ...| Life Is All You Get| 10018|berlin newlove st...|   13|
# |[catherinesteadma...|         stevebarker|[bunker, nazis, e...|    [action, horror]|  Outpost: Black Sun|100183|bunker nazis east...|   14|
# |[christianslater,...|            alanwade|         [smalltown]|[comedy, drama, r...|           Julian Po|100196|smalltown christi...|   15|
# |        [frankzappa]|          frankzappa|                  []|                  []|         Baby Snakes|100205| frankzappa frank...|   16|
# |[michaelj.fox, he...|         herbertross|[dualidentity, mi...|            [comedy]|The Secret of My ...| 10021|dualidentity mist...|   17|
# |[wernerherzog, st...|        wernerherzog|[pennsylvania, au...|       [documentary]|How Much Wood Wou...|100224|pennsylvania auct...|   18|
# |[camerondiaz, ale...|      nickcassavetes|[parentchildrelat...|             [drama]|  My Sister's Keeper| 10024|parentchildrelati...|   19|
# |[lindsaylohan, sa...|        donaldpetrie|[jinx, badluck, k...|[comedy, drama, f...|        Just My Luck| 10025|jinx badluck kiss...|   20|
# +--------------------+--------------------+--------------------+--------------------+--------------------+------+--------------------+-----+
# only showing top 20 rows

# %%
# dict_data= df_7.select('id','title')

# %%
# dict_data.show()
# Out:
# +---+--------------------+
# | id|               title|
# +---+--------------------+
# |  0|The Age of Innocence|
# |  1|Common Threads: S...|
# |  2|           C'mon Man|
# |  3|    Brown of Harvard|
# |  4|     Golden Earrings|
# |  5|Kids of the Round...|
# |  6|            Released|
# |  7|      Donovan's Echo|
# |  8|             Impulse|
# |  9|         Calm at Sea|
# | 10|            14782676|
# | 11|                  41|
# | 12|           Bongwater|
# | 13|           Chop Shop|
# | 14|             Big Sur|
# | 15|Die Hard: With a ...|
# | 16|   May in the Summer|
# | 17|   Love Comes Softly|
# | 18|One Direction: Th...|
# | 19|        Bag of Bones|
# +---+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.types import IntegerType
# Function that takes in movie title as input and outputs most similar movies
def get_recommendations(title, cosine_sim=cosine_sim):
    index= df_7.where(col("title")==title).collect()[0]["index"]
    sim_scores = list(enumerate(cosine_sim[int(index)]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    movie_indices = [i[0] for i in sim_scores]
    recommendations = spark.createDataFrame(movie_indices, IntegerType())
    # recommendations.show()
    df_7.join(recommendations,recommendations.value==df_7.index).select(col('id'),col('title')).show()

# %%
get_recommendations('Jumanji')
# Out:
# +-----+
# |value|
# +-----+
# | 9692|
# |15070|
# |18377|
# | 5157|
# | 6133|
# | 8956|
# | 2731|
# | 3166|
# | 5056|
# |10632|
# +-----+
#
# +------+--------------------+
# |    id|               title|
# +------+--------------------+
# | 18468|         Momma's Man|
# | 35119|   A Cry in the Dark|
# | 60573|     The Burning Bed|
# | 14358|                null|
# | 18242|The Secret Advent...|
# |308027|People, Places, T...|
# | 96239|Remington and the...|
# |284581|Back Issues: The ...|
# |137217|      Donovan's Echo|
# |  2072|           Cyberjack|
# +------+--------------------+

# %%
df_final.count()
# Out:
# 18704
